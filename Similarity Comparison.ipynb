# %% [markdown]
# ## Convert Data set to embeddings first

# %%
def convert_column_to_embeddings(df, column_name):
    # Check if the column exists in the DataFrame
    if column_name not in df.columns:
        raise ValueError(f"Column '{column_name}' not found in the dataset")

    # Iterate through each entry in the specified column and get embeddings
    for index, row in df.iterrows():
        if index%20 == 0:
            print(f"Embedding... founder number {index}, attribute: {column_name}")
        try:
            # Apply embed_text function to each cell in the column
            if df.at[index, column_name][1] == '(':
                df.at[index, column_name] = embed_text(row[column_name])
        except Exception as e:
            print(f"Error processing row {index}: {e}")

    return df

# %%
# Convert all meaningful detail used for comparing similarity into embeddings
column_names_to_convert = ['Self-Description', 'long_description', 'category_list', 'category_groups_list', 'Employment Backgrounds', 'Education Backgrounds']

df = pd.read_csv("Founder Features with embeddings.csv")
for column_name in column_names_to_convert[4:]:
    df = convert_column_to_embeddings(df, column_name)
# Out:
# Embedding... founder number 0, attribute: Employment Backgrounds
# Embedding... founder number 20, attribute: Employment Backgrounds
# Embedding... founder number 40, attribute: Employment Backgrounds
# Embedding... founder number 60, attribute: Employment Backgrounds
# Embedding... founder number 80, attribute: Employment Backgrounds
# Embedding... founder number 100, attribute: Employment Backgrounds
# Embedding... founder number 120, attribute: Employment Backgrounds
# Embedding... founder number 140, attribute: Employment Backgrounds
# Embedding... founder number 160, attribute: Employment Backgrounds
# Embedding... founder number 180, attribute: Employment Backgrounds
# Embedding... founder number 200, attribute: Employment Backgrounds
# Embedding... founder number 220, attribute: Employment Backgrounds
# Embedding... founder number 240, attribute: Employment Backgrounds
# Embedding... founder number 260, attribute: Employment Backgrounds
# ...

# %%
df
# Out:
#            ID  isSuccess               Name Gender   Age  \
# 0         0_S       True         Ryan Johns   Male  44.0
# 1         1_S       True      Shoaib Makani   Male  38.0
# 2         2_S       True         Obaid Khan   Male  35.0
# 3         3_S       True        Alex Buttle   Male  44.0
# 4         4_S       True        Harry Jones   Male  39.0
# ...       ...        ...                ...    ...   ...
# 10061  5993_F      False        James Welsh    NaN  47.0
# 10062  5994_F      False        Nick Tackes    NaN  56.0
# 10063  5995_F      False   Akinori Takahagi   Male   NaN
# 10064  5996_F      False  Motohiro Yonesaka   Male  42.0
# 10065  5997_F      False    Matthew Tullman    NaN   NaN
#
#                                            linkedin_url  \
# 0            https://www.linkedin.com/in/ryan-johns-sf/
# 1                    http://www.linkedin.com/in/smakani
# 2      https://www.linkedin.com/in/obaid-khan-b77b4357/
# ...

# %%
df.to_csv('Founder Features with Embeddings.csv', index=False)

# %% [markdown]
# ### Split the embedding data into training and testing sets, ratio 9:1

# %%
import pandas as pd
from sklearn.model_selection import train_test_split

def split_and_save_csv(input_file, output_file1, output_file2, split_ratio=0.9, random_state=None):
    # Read the data from the input CSV file into a DataFrame
    df = pd.read_csv(input_file)
    
    df_succ = df[df['isSuccess'] == True]
    df_fail = df[df['isSuccess'] == False]

    # Split the DataFrame into two parts: 90% and 10%
    df1_succ, df2_succ = train_test_split(df_succ, train_size=split_ratio, random_state=random_state)
    df1_fail, df2_fail = train_test_split(df_fail, train_size=split_ratio, random_state=random_state)

    # Write the first DataFrame to the first output CSV file
    combined_train = pd.concat([df1_succ, df1_fail], ignore_index=True)
    combined_train.to_csv(output_file1, index=False)

    # Write the second DataFrame to the second output CSV file
    combined_test = pd.concat([df2_succ, df2_fail], ignore_index=True)
    combined_test.to_csv(output_file2, index=False)

# Example usage:
input_file = 'Founder Features with Embeddings.csv'
output_file1 = 'Founder Features with Embeddings_Training.csv'
output_file2 = 'Founder Features with Embeddings_Testing.csv'
split_and_save_csv(input_file, output_file1, output_file2)

# %% [markdown]
# ## Generate Rubrics for similarity scores

# %%
# Extract a random 50 successful and 50 unsuccessful founder details to be fed into GPT
df = pd.read_csv('Founder Features.csv')

df_succ = df[df['isSuccess'] == True]
df_fail = df[df['isSuccess'] == False]

random_sample_succ = df_succ.sample(n = 50)
random_sample_fail = df_fail.sample(n = 50)
combined = pd.concat([random_sample_succ, random_sample_fail], ignore_index=True)
combined.to_csv("Sample Founder Features 5.csv", index = False)

# %% [markdown]
# ### Functions used to calculate similarity between input properties

# %%
import re
import string
import ast
import numpy as np
import pandas as pd
from openai import OpenAI
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.feature_extraction.text import ENGLISH_STOP_WORDS

OPENAI_API_KEY = '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'
client = OpenAI(api_key = OPENAI_API_KEY)

# Function to clean and tokenize text
def clean_and_tokenize(text):
    # Convert to lower case
    text = text.lower()
    # Remove punctuation
    text = re.sub(f"[{string.punctuation}]", " ", text)
    # Tokenization and removing stopwords
    tokens = text.split()
    tokens = [token for token in tokens if token not in ENGLISH_STOP_WORDS]
    return tokens

# OpenAI API call for embeddings
def openai_embed_text(tokens):
    # Convert tokens back to text
    cleaned_text = " ".join(tokens)
    
    # Making a call to the OpenAI API
    response = client.embeddings.create(
        model="text-embedding-ada-002",
        input=cleaned_text,
        encoding_format="float"
    )

    # Extracting embeddings from the response
    embeddings = response.data[0].embedding
    return embeddings

# The complete embed_text function
def embed_text(text):
    # Clean and tokenize the text
    tokens = clean_and_tokenize(text)
    # Get embeddings using OpenAI (placeholder implementation)
    embeddings = openai_embed_text(tokens)
    return embeddings


# Function to calculate cosine similarity
def calculate_similarity(new_founder_profile, existing_embeddings):
    """
    Input: new_founder_profile : String
           existing_profiles: List<Embeddings>
    """
    # Embed the new founder's profile
    new_founder_embedding = embed_text(new_founder_profile)

    # Embed the existing profiles, converting string to the list representation
    aList = []
    for embedding_str in existing_embeddings:
        if embedding_str != "[]":
            try:
                aList.append(ast.literal_eval(embedding_str))
            except:
                aList.append(embed_text(""))
        else:
            aList.append(embed_text(""))
    existing_embeddings = np.array(aList)

    # Calculate cosine similarity
    similarity_scores = cosine_similarity([new_founder_embedding], existing_embeddings)

    return similarity_scores[0]

# %%
# Example usage: comparing business idea in company's long description
df = pd.read_csv("Founder Features with Embeddings_Testing.csv")

existing_profiles_embeddings = list(df['Education Backgrounds'][:10].fillna('') )
new_founder_profile = "Nuvemshop provides entrepreneurs and SMBs with the tools to set up, manage, and promote their online business easily from any device. With the suite of tools around payments, shipping, inventory management, and marketing provided by the company, owners are enabled to participate in the e-commerce market, ramp up their sales, reduce costs, and provide their end customers with a shopping experience. In 2011, co-founders Alejandro Alfonso, Santiago Sosa, Jose Abuchaem, Martin Palombo, and Alejandro Vazquez established Nuvemshop in 2011."

similarity_scores = calculate_similarity(new_founder_profile, existing_profiles_embeddings)
print(similarity_scores)

# Get the top 3-5 matches
num_matches = 5
top_matches_indices = np.argsort(similarity_scores)[-num_matches:][::-1]
top_matches = df.iloc[top_matches_indices]

top_matches
# Out:
# [0.70027772 0.73104211 0.73874382 0.69913911 0.73159092 0.71702113
#  0.7304396  0.75679118 0.71320256 0.73610698]
#        ID  isSuccess             Name  Gender   Age  \
# 7  3101_S       True      Richard Koh    Male  50.0
# 2  1235_S       True    Pekka Laurila    Male  33.0
# 9   940_S       True   Alberto Toledo    Male  44.0
# 4  1941_S       True  Daniel Kirchert     NaN  47.0
# 1  1715_S       True   Julien Lemoine  Female  42.0
#
#                                         linkedin_url  \
# 7   https://www.linkedin.com/in/richard-koh-b928974/
# 2  https://www.linkedin.com/in/pekka-laurila-bb2a...
# 9    https://www.linkedin.com/in/albertolopeztoledo/
# 4  https://www.linkedin.com/in/dr-daniel-kirchert...
# 1           http://www.linkedin.com/in/julienlemoine
#
#                                     Self-Description  \
# 7  [0.008408013, -0.014242706, 0.0071901586, -0.0...
# 2  [0.005814258, -0.01378771, -0.00064682774, -0....
# ...

# %% [markdown]
# ### Create a similarity score for each of the core features
#
# features include: self-description, education backgrounds, employment backgrouds, long descriptions, category_list, category_groups_list

# %%
def calculate_aggregate_similarity(training_file, new_founder_profile, num_matches = 5):
    """
    Input: training_file: file name of embeddings file for training
           new_founder_profile: the row in the Founder Features.csv for the new founder
           num_matches: Int
    """
    columns_to_compare = ["Self-Description", "Education Backgrounds", "Employment Backgrounds", "long_description", "category_list"]
    attribute_weights = [2.66, 0.69, 1.85, 1.71, 3.08] #Weight obtained from GPT analysis
    
    df = pd.read_csv(training_file)
    aggregate_similarity = [0] * (len(df) + 1)

    for i, column in enumerate(columns_to_compare):
        existing_profiles_embeddings = list(df[column].fillna('') )
        new_founder_attribute = str(new_founder_profile[column])

        similarity_scores = calculate_similarity(new_founder_attribute, existing_profiles_embeddings)
        for index in range(len(similarity_scores)):
            aggregate_similarity[index] += attribute_weights[i] * similarity_scores[index]
        print(column)
        print(similarity_scores[:10])
        print(aggregate_similarity[:10])

    # Get the top 3-5 matches
    top_matches_indices = np.argsort(aggregate_similarity)[-num_matches:][::-1]
    top_matches = df.iloc[top_matches_indices]

    return top_matches

# %%
# Example usage
training_file = "Founder Features with Embeddings_Training.csv"
new_founder_id = "1772_F"
df = pd.read_csv("Founder Features.csv")
search_result = df[df["ID"] == new_founder_id]
new_founder_profile = search_result.iloc[0]
search_result.to_csv("Input Founder Features.csv", index = False)
top_matches = calculate_aggregate_similarity(training_file, new_founder_profile, num_matches = 5)
top_matches
# Out:
# Self-Description
# [0.83102704 0.79780841 0.79458283 0.81107553 0.79770721 0.81015378
#  0.79378316 0.84194076 0.78654688 0.81904372]
# [2.2105319256709035, 2.1221703697397354, 2.1135903403938374, 2.1574609035562005, 2.1219011783332657, 2.155009055861782, 2.111463203451711, 2.239562433929092, 2.092214703710955, 2.1786563002580843]
# Education Backgrounds
# [0.78556413 0.79515195 0.79898215 0.83280862 0.66331161 0.77182029
#  0.78785127 0.80635147 0.80553839 0.81538837]
# [2.7525711742375565, 2.6708252174038676, 2.6648880210517163, 2.7320988540394078, 2.5795861895468115, 2.6875650578848354, 2.655080580907824, 2.7959449503548415, 2.6480361931390655, 2.7412742779544486]
# Employment Backgrounds
# [0.87747653 0.84192152 0.81743914 0.87677592 0.87119349 0.8405225
#  0.84760059 0.86240513 0.88152788 0.8862728 ]
# ...

# %%
# Exporting results to new file
df = pd.read_csv("Founder Features.csv")
founder_ids = []
for index, row in top_matches.iterrows():
    founder_ids.append(row["ID"])
    
matching_rows = []
for index, row in df.iterrows():
    if row["ID"] in founder_ids:
        matching_rows.append(row)
    
new_df = pd.DataFrame(matching_rows)
new_df.to_csv("Top Similar Founders.csv")

# %% [markdown]
# ## Using Pinecone for vector database

# %%
import pinecone
import openai
import pandas as pd
import ast

PINECONE_API = "3a52b152-07ce-464e-8ce8-f04c3fad9850"
dataPath = "Founder Features with Embeddings_Training.csv"

pinecone.init(api_key=PINECONE_API, environment="gcp-starter")
pinecone.create_index("founder-profiles", dimension=1536, metric="cosine")
pinecone.describe_index("founder-profiles")
# Out:
# IndexDescription(name='founder-profiles', metric='cosine', replicas=1, dimension=1536.0, shards=1, pods=1, pod_type='starter', status={'ready': True, 'state': 'Ready'}, metadata_config=None, source_collection='')

# %%
index = pinecone.Index("founder-profiles")
index.describe_index_stats()
# Out:
# {'dimension': 1536,
#  'index_fullness': 0.0,
#  'namespaces': {},
#  'total_vector_count': 0}

# %%
# Upload vector data into the database
import itertools

def obtain_data(dataPath, field_name):
    data = pd.read_csv(dataPath)
    data_generator = []
    for i, row in data.iterrows():
        try:
            embedding = ast.literal_eval(row[field_name])
            if len(embedding) == 1536:
                data_generator.append((row["ID"], embedding))
        except:
            print(f"Error in embedding at row {i}. Data not added.")
    return data_generator

def upload_vectors_to_pinecone(index, data_generator, field_name):
    # Assuming iterable is a list of tuples (id, vector)
    def chunks(iterable, batch_size=100):
        """A helper function to break an iterable into chunks of size batch_size."""
        it = iter(iterable)
        chunk = tuple(itertools.islice(it, batch_size))
        while chunk:
            yield chunk
            chunk = tuple(itertools.islice(it, batch_size))
    
    # Upsert data with 100 vectors per upsert request
    for ids_vectors_chunk in chunks(data_generator, batch_size=100):
        index.upsert(vectors=ids_vectors_chunk, 
                     namespace = field_name)


index = pinecone.Index("founder-profiles")
data_generator = obtain_data(dataPath, 'category_list')
upload_vectors_to_pinecone(index, data_generator, 'category_list')
index.describe_index_stats()
# Out:
# Error in embedding at row 92. Data not added.
# Error in embedding at row 143. Data not added.
# Error in embedding at row 401. Data not added.
# Error in embedding at row 566. Data not added.
# Error in embedding at row 619. Data not added.
# Error in embedding at row 650. Data not added.
# Error in embedding at row 1025. Data not added.
# Error in embedding at row 1808. Data not added.
# Error in embedding at row 1977. Data not added.
# Error in embedding at row 2367. Data not added.
# Error in embedding at row 2390. Data not added.
# Error in embedding at row 2429. Data not added.
# Error in embedding at row 2816. Data not added.
# Error in embedding at row 3474. Data not added.
# Error in embedding at row 3661. Data not added.
# Error in embedding at row 4427. Data not added.
# Error in embedding at row 4508. Data not added.
# Error in embedding at row 4524. Data not added.
# Error in embedding at row 4546. Data not added.
# Error in embedding at row 4594. Data not added.
# ...

# %%
# Query for the cosine similarity
def query_pinecone_for_similarity(index, query_vector, top_k):
    return index.query(queries=[query_vector], top_k=top_k)
